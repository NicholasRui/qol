# %% [markdown]
# Purpose: To test the new functionality I put into the pyplot wrapper.

# %%
import qol.vis.pyplot as plt # add default boilerplate I put at top of doc
import numpy as np

# %%
ax = plt.axes()

ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.set_title('title')

x = np.linspace(0.01, 1, 100)

ax.plot(x, x**2)
ax.plot(x, x**3)
ax.plot(x, x**4)
ax.plot(x, x**2+0.2)

plt.loglog()

# plt.axes()

plt.show()
# Out:
# xlabel

# %%
type(ax)
# Out:
# qol.vis.FancyAxes.FancyAxes
