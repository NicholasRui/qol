# %% [markdown]
# Purpose: To test the new functionality I put into the pyplot wrapper.

# %%
import qol.vis.pyplot as plt
import numpy as np

# %%
ax = plt.axes()

ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.set_title('title')

x = np.linspace(0.01, 1, 100)

ax.plot(x, x**2)
ax.plot(x, x**3)
ax.plot(x, x**4)
ax.plot(x, x**2+0.2)

ax.scatter(x, x**2)
ax.scatter(x, x**3)
ax.scatter(x, x**4, edgecolor='k')
ax.scatter(x, x**2+0.2, edgecolor='k', zorder=5, lw=10)

plt.loglog()

# plt.axes()

plt.show()

# %%
ax = plt.axes(blank=True)

ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.set_title('title')

x = np.linspace(0.01, 1, 100)

ax.plot(x, x**2)
ax.plot(x, x**3)
ax.plot(x, x**4)
ax.plot(x, x**2+0.2)

ax.scatter(x, x**2)
ax.scatter(x, x**3)
ax.scatter(x, x**4, edgecolor='k')
ax.scatter(x, x**2+0.2, edgecolor='k', zorder=5, lw=10)

plt.loglog()

# plt.axes()

plt.show()

# %%
x = np.linspace(0.01, 1, 100)

plt.plot(x, x**2)
plt.plot(x, x**3)
plt.plot(x, x**4)
plt.plot(x, x**2+0.2)

plt.scatter(x, x**2)
plt.scatter(x, x**3)
plt.scatter(x, x**4, edgecolor='k')
plt.scatter(x, x**2+0.2, edgecolor='k', zorder=5, lw=10)

plt.loglog()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 plt.plot(x, x**4)
#       6 plt.plot(x, x**2+0.2)
# ----> 8 plt.scatter(x, x**2)
#       9 plt.scatter(x, x**3)
#      10 plt.scatter(x, x**4, edgecolor='k')
#
# File ~/Desktop/pythonpath/qol/vis/pyplot.py:187, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#     150 def scatter(
#     151     x: float | ArrayLike,
#     152     y: float | ArrayLike,
#    (...)
#     167     **kwargs,
#     168 ) -> PathCollection:
#     169     __ret = gca().scatter(
#     170         x,
#     171         y,
#    (...)
#     185         **kwargs,
#     186     )
# --> 187     sci(__ret)
#     188     return __ret
#
# File ~/Desktop/pythonpath/qol/vis/pyplot.py:132, in sci(im)
#     131 def sci(im: ColorizingArtist) -> None:
# ...

# %%
print(f"gca(): {plt.gca()}")
print(f"type(gca()): {type(plt.gca())}")
print(f"gca().scatter: {plt.gca().scatter}")
